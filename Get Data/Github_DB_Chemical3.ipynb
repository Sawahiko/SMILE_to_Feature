# %%
from chemicals import CAS_from_any, Tb
import chemicals.critical as ct
import chemicals.phase_change
import chemicals.data_reader as cd

# %%
import chemicals
chemicals.vapor_pressure.Psat_data_Perrys2_8
# Out:
#                            Chemical       C1        C2       C3            C4  \
# CAS
# 50-00-0               Formaldehyde   101.510  -4917.20 -13.7650  2.203100e-02
# 55-21-0                 Benzamide     85.474 -11932.00  -8.3348  1.285000e-18
# 56-23-5       Carbon tetrachloride    78.441  -6128.10  -8.5766  6.846500e-06
# 57-55-6      1,2-Propylene glycol    212.800 -15420.00 -28.1090  2.156400e-05
# 60-29-7             Diethyl ether    136.900  -6954.30 -19.2540  2.450800e-02
# ...                             ...      ...       ...      ...           ...
# 10028-15-6                  Ozone     40.067  -2204.80  -2.9351  7.752000e-16
# 10035-10-6       Hydrogen bromide     29.315  -2424.50  -1.1354  2.380600e-18
# 10102-43-9           Nitric oxide     72.974  -2650.00  -8.2610  9.700000e-15
# 13511-13-2    Propenylcyclohexene     64.268  -7298.90  -5.9109  4.848200e-18
# 132259-10-0                   Air     21.662   -692.39  -0.3920  4.757400e-03
#
#               C5    Tmin    Tmax
# CAS
# 50-00-0      1.0  181.15  408.00
# 55-21-0      6.0  403.00  824.00
# 56-23-5      2.0  250.33  556.35
# 57-55-6      2.0  213.15  626.00
# 60-29-7      1.0  156.85  466.70
# ...          ...     ...     ...
# 10028-15-6   6.0   80.15  261.00
# 10035-10-6   6.0  185.15  363.15
# 10102-43-9   6.0  109.50  180.15
# 13511-13-2   6.0  199.00  636.00
# 132259-10-0  1.0   59.15  132.45
#
# [340 rows x 8 columns]

# %%
chemicals.vapor_pressure.Psub_data_Landolt_Antoine
# Out:
#                                                           Name          A  \
# CAS
# 50-29-3      2,2-Bis(4-chlorophenyl)-1,1,1-trichloroethane,...  29.899113
# 50-32-8                                         Benzo[a]pyrene  33.633170
# 50-36-2                                                Cocaine  34.872651
# 51-17-2                                          Benzimidazole  33.548665
# 51-28-5                                      2,4-Dinitrophenol  36.971895
# ...                                                        ...        ...
# 900000-38-6  Hexamethylbenzene-1-chloro-2,4,6-trinitrobenze...  33.458634
# 900000-42-2               Hydrido-hexacarbonyl-rhenium complex  24.690620
# 900001-70-9        Bis(chloroethylene)(2,4-pentandione)iridium  31.242165
# 900001-71-0       Bis(chloroethylene)(2,4-pentandione)-rhodium  44.472359
# 900002-52-0                 2,4-Dimethyl-1,3,5-trinitrobenzene  40.824834
#
#                         B       C   Tmin   Tmax
# CAS
# 50-29-3      10344.335899 -37.012  293.0  354.0
# 50-32-8      14232.278460   0.000  358.0  431.0
# 50-36-2      13548.410687   0.000  294.0  314.0
# 51-17-2      12242.844939   0.000  323.0  340.0
# 51-28-5      12556.259007  -0.399  293.0  333.0
# ...                   ...     ...    ...    ...
# 900000-38-6  11267.469894   0.000  478.0  631.0
# 900000-42-2   5419.364275   0.000  279.0  369.0
# 900001-70-9  10912.526402   0.000  281.0  298.0
# 900001-71-0  14374.394012   0.000  274.0  288.0
# 900002-52-0  15609.224345   0.000  318.0  412.0
#
# [1084 rows x 6 columns]

# %%
chemicals.dippr.
# Out:
# <module 'chemicals.dippr' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\chemicals\\dippr.py'>
