# %%
from chemicals import CAS_from_any, Tb
import chemicals.critical as ct
import chemicals.phase_change
import chemicals.data_reader as cd
import chemicals

# %%
chemicals.volume.rho_data_Perry_8E_105_l
# Out:
#                           Chemical       C1       C2      C3       C4    Tmin  \
# CAS
# 50-00-0              Formaldehyde   1941.50  0.22309  408.00  0.28571  181.15
# 55-21-0                 Benzamide    737.10  0.25487  824.00  0.28571  403.00
# 56-23-5      Carbon tetrachloride    998.35  0.27400  556.35  0.28700  250.33
# 57-55-6      1,2-Propylene glycol   1092.30  0.26106  626.00  0.20459  213.15
# 60-29-7             Diethyl ether    955.40  0.26847  466.70  0.28140  156.85
# ...                            ...      ...      ...     ...      ...     ...
# 10028-15-6                  Ozone   3359.20  0.29884  261.00  0.28523   80.15
# 10035-10-6       Hydrogen bromide   2832.00  0.28320  363.15  0.28571  185.15
# 10102-43-9           Nitric oxide   5246.00  0.30440  180.15  0.24200  109.50
# 13511-13-2    Propenylcyclohexene    612.55  0.26769  636.00  0.28571  199.00
# 132259-10-0                   Air   2896.30  0.26733  132.45  0.27341   59.15
#
#                Tmax
# CAS
# 50-00-0      408.00
# 55-21-0      824.00
# 56-23-5      556.35
# 57-55-6      626.00
# 60-29-7      466.70
# ...             ...
# 10028-15-6   261.00
# 10035-10-6   363.15
# 10102-43-9   180.15
# 13511-13-2   636.00
# 132259-10-0  132.45
#
# [344 rows x 7 columns]

# %%
def showdf(df):
    print(df.shape)
    return df.head()

# %%
df1 = chemicals.volume.rho_data_Perry_8E_105_l
showdf(df1)
df1.to_csv("Liquid_morlar_density_raw1.csv")
# Out:
# (344, 7)
