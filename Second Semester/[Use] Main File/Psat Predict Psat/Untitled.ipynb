# %%
import pyautogui
import time
import playsound
import keyboard
from IPython.display import  Audio
import pygame
time.sleep(10)
x, y = 1200, 140
width, height = 100,100

initial_image = pyautogui.screenshot(region=(x, y, width, height))
while True:
    current_image = pyautogui.screenshot(region=(x, y, width, height))
    
    if current_image != initial_image:
        print("Change detected")
        
        
        #playsound.playsound(soundpath2)
        #pygame.mixer.init()
        #pygame.mixer.Sound(soundpath2)
        #time.sleep(5)
        initial_image = current_image
        break
    
    if keyboard.is_pressed("esc"):
        print("Stop")
        break
    
    time.sleep(0.5)
    print(f"Mouse position : {pyautogui.position()}")
    
soundpath = r"C:/Users/Kan/Downloads/acoustic-guitar-loop-f-91bpm-132687.mp3"
soundpath2 = r"C:/Users/Kan/Downloads/acoustic-guitar-loop-f-91bpm-132687.wav"

path = r"C:\Users\Kan\Desktop\Entertainment\Granny go Japan!.mp3"
Audio(data = soundpath , autoplay = True)
# Out:
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# Mouse position : Point(x=498, y=673)
# ...
